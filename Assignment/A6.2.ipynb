# %% [markdown]
# # 01 Import Libraries and Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# create a path
path = r'C:\Users\bulle\Documents\Python Scripts\Achievement6'

# %%
# Load data, uft-8 doesn't support coding, use encoding='ISO-8859-1' 
df= pd.read_csv(r'C:\Users\bulle\Documents\Python Scripts\Achievement6\Data\Prepared Data\movie_data_clean.csv', encoding='ISO-8859-1',index_col = False)

# %% [markdown]
# # 02 Data Cleaning

# %%
df.head()
# Out:
#   movie_title  duration  title_year    director_name     actor_1_name  \
# 0        2:13      96.0      2009.0  Charles Adelman        Teri Polo
# 1       11:14      85.0      2003.0      Greg Marcks     Henry Thomas
# 2           3     119.0      2010.0       Tom Tykwer   Devid Striesow
# 3           9     112.0      1986.0      Adrian Lyne  David Margulies
# 4           9      79.0      2009.0      Shane Acker    Martin Landau
#
#          actor_2_name  actor_3_name language  country content_rating  \
# 0        Kevin Pollak    Jere Burns  English      USA            NaN
# 1     Barbara Hershey  Shawn Hatosy  English      USA              R
# 2  Sebastian Schipper   Sophie Rois   German  Germany        Unrated
# 3         Karen Young      Kim Chan  English      USA              R
# 4    Alan Oppenheimer      Tom Kane  English      USA          PG-13
#
#    num_critic_for_reviews  director_facebook_likes      budget       gross  \
# ...

# %%
df.shape
# Out:
# (4920, 19)

# %%
df.describe().round()
# Out:
#        duration  title_year  num_critic_for_reviews  director_facebook_likes  \
# count    4905.0      4814.0                  4871.0                   4818.0
# mean      107.0      2002.0                   138.0                    691.0
# std        25.0        12.0                   120.0                   2832.0
# min         7.0      1916.0                     1.0                      0.0
# 25%        93.0      1999.0                    49.0                      7.0
# 50%       103.0      2005.0                   108.0                     48.0
# 75%       118.0      2011.0                   192.0                    190.0
# max       511.0      2016.0                   813.0                  23000.0
#
#              budget        gross  cast_total_facebook_likes  imdb_score
# count  4.436000e+03       4057.0                     4920.0      4920.0
# mean   3.929891e+07   47616851.0                     9581.0         6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                4920 non-null   object
#  1   duration                   4905 non-null   float64
#  2   title_year                 4814 non-null   float64
#  3   director_name              4818 non-null   object
#  4   actor_1_name               4913 non-null   object
#  5   actor_2_name               4907 non-null   object
#  6   actor_3_name               4897 non-null   object
#  7   language                   4908 non-null   object
#  8   country                    4915 non-null   object
#  9   content_rating             4619 non-null   object
#  10  num_critic_for_reviews     4871 non-null   float64
#  11  director_facebook_likes    4818 non-null   float64
#  12  budget                     4436 non-null   float64
# ...

# %%
df.head()
# Out:
#   movie_title  duration  title_year    director_name     actor_1_name  \
# 0        2:13      96.0      2009.0  Charles Adelman        Teri Polo
# 1       11:14      85.0      2003.0      Greg Marcks     Henry Thomas
# 2           3     119.0      2010.0       Tom Tykwer   Devid Striesow
# 3           9     112.0      1986.0      Adrian Lyne  David Margulies
# 4           9      79.0      2009.0      Shane Acker    Martin Landau
#
#          actor_2_name  actor_3_name language  country content_rating  \
# 0        Kevin Pollak    Jere Burns  English      USA            NaN
# 1     Barbara Hershey  Shawn Hatosy  English      USA              R
# 2  Sebastian Schipper   Sophie Rois   German  Germany        Unrated
# 3         Karen Young      Kim Chan  English      USA              R
# 4    Alan Oppenheimer      Tom Kane  English      USA          PG-13
#
#    num_critic_for_reviews  director_facebook_likes      budget       gross  \
# ...

# %%
# Looking for NaN and delete them
df.isnull().sum()
# Out:
# movie_title                    0
# duration                      15
# title_year                   106
# director_name                102
# actor_1_name                   7
# actor_2_name                  13
# actor_3_name                  23
# language                      12
# country                        5
# content_rating               301
# num_critic_for_reviews        49
# director_facebook_likes      102
# budget                       484
# gross                        863
# genres                         0
# cast_total_facebook_likes      0
# imdb_score                     0
# color                         19
# plot_keywords                151
# dtype: int64

# %%
df=df.fillna({'language':'No data','country': 'No data','color': 'No data'})

# %%
df=df.dropna(subset=['duration','title_year','budget','gross', 'num_critic_for_reviews'])

# %%
df.shape
# Out:
# (3789, 19)

# %%
# Downsizing dataset
df['title_year']=df['title_year'].astype('int16')
df['duration']=df['duration'].astype('int16')
df['num_critic_for_reviews']=df['num_critic_for_reviews'].astype('int16')
df['director_facebook_likes']=df['director_facebook_likes'].astype('int16')
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')
df['imdb_score']=df['imdb_score'].astype('int16')

# %%
# Check for duplicate

for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
# Out:
# actor_1_name
# actor_2_name
# actor_3_name
# content_rating
# plot_keywords

# %%
df['actor_1_name'] = df['actor_1_name'].astype('str')
df['actor_2_name'] = df['actor_2_name'].astype('str')
df['actor_3_name'] = df['actor_3_name'].astype('str')
df['content_rating'] = df['content_rating'].astype('str')
df['plot_keywords'] = df['plot_keywords'].astype('str')

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3789 entries, 3 to 4918
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                3789 non-null   object
#  1   duration                   3789 non-null   int16
#  2   title_year                 3789 non-null   int16
#  3   director_name              3789 non-null   object
#  4   actor_1_name               3789 non-null   object
#  5   actor_2_name               3789 non-null   object
#  6   actor_3_name               3789 non-null   object
#  7   language                   3789 non-null   object
#  8   country                    3789 non-null   object
#  9   content_rating             3789 non-null   object
#  10  num_critic_for_reviews     3789 non-null   int16
#  11  director_facebook_likes    3789 non-null   int16
#  12  budget                     3789 non-null   int64
# ...

# %%
df.describe().round()
# Out:
#        duration  title_year  num_critic_for_reviews  director_facebook_likes  \
# count    3789.0      3789.0                  3789.0                   3789.0
# mean      110.0      2003.0                   161.0                    787.0
# std        23.0        10.0                   123.0                   3038.0
# min        34.0      1920.0                     1.0                      0.0
# 25%        95.0      1999.0                    71.0                     10.0
# 50%       105.0      2005.0                   131.0                     58.0
# 75%       120.0      2010.0                   218.0                    221.0
# max       330.0      2016.0                   813.0                  23000.0
#
#              budget        gross  cast_total_facebook_likes  imdb_score
# count  3.789000e+03       3789.0                     3789.0      3789.0
# mean   4.472386e+07   50212967.0                    11125.0         6.0
# ...

# %%
df.shape
# Out:
# (3789, 19)

# %%
df2=df.drop(columns = ['actor_1_name', 'actor_2_name','actor_3_name'])

# %%
df.to_csv(os.path.join(path, 'Data','Prepared Data', 'movie_data_pythonclean.csv'))

# %%
df2.to_csv(os.path.join(path, 'Data','Prepared Data', 'movie_data_nameclean.csv'))

# %%
df2.head()
# Out:
#   movie_title  duration  title_year     director_name language country  \
# 3           9       112        1986       Adrian Lyne  English     USA
# 4           9        79        2009       Shane Acker  English     USA
# 5          21       123        2008    Robert Luketic  English     USA
# 6          42       128        2013   Brian Helgeland  English     USA
# 7          54       121        1998  Mark Christopher  English     USA
#
#   content_rating  num_critic_for_reviews  director_facebook_likes    budget  \
# 3              R                      38                      213  17000000
# 4          PG-13                     263                       30  30000000
# 5          PG-13                     144                      126  35000000
# 6          PG-13                     216                      241  40000000
# 7              R                      63                       15  13000000
#
#       gross                                             genres  \
# ...

# %% [markdown]
# # 03 Exploring Relationships

# %%
# Create a correlation matrix using pandas

df.corr()
# Out:
#                            duration  title_year  num_critic_for_reviews  \
# duration                   1.000000   -0.133886                0.233826
# title_year                -0.133886    1.000000                0.392442
# num_critic_for_reviews     0.233826    0.392442                1.000000
# director_facebook_likes    0.183543   -0.047311                0.183620
# budget                     0.066340    0.042048                0.103885
# gross                      0.246167    0.037965                0.466922
# cast_total_facebook_likes  0.122297    0.118574                0.239878
# imdb_score                 0.347186   -0.114514                0.338152
#
#                            director_facebook_likes    budget     gross  \
# duration                                  0.183543  0.066340  0.246167
# title_year                               -0.047311  0.042048  0.037965
# num_critic_for_reviews                    0.183620  0.103885  0.466922
# ...

# %%
df=df[['duration','title_year','num_critic_for_reviews','director_facebook_likes','budget','gross','cast_total_facebook_likes','imdb_score''']]

# %% [markdown]
# ## Correlation heatmap

# %%
# Create a correlation heatmap using matplotlib
# Save figure
plt.matshow(df.corr())
plt.savefig("Netcorr.png")

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\bulle\\Documents\\Python Scripts\\Achievement6\\6.2'

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=12, rotation=80) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Looking at the heatmap, it seems like the factors don't have a strong relationship. some of them have a moderate relationship such as when gross income of a movie is high, the number of critic for reviews is high. Also, new movies have more number of critic for reviews than the old movies as well.

# %%
# Create a correlation heatmap using seaborn
df.columns
# Out:
# Index(['duration', 'title_year', 'num_critic_for_reviews',
#        'director_facebook_likes', 'budget', 'gross',
#        'cast_total_facebook_likes', 'imdb_score'],
#       dtype='object')

# %%
# Create a subset 

sub = df[['duration', 'title_year', 'num_critic_for_reviews',
       'director_facebook_likes', 'budget', 'gross',
       'cast_total_facebook_likes', 'imdb_score']]

# %%
sub
# Out:
#       duration  title_year  num_critic_for_reviews  director_facebook_likes  \
# 3          112        1986                      38                      213
# 4           79        2009                     263                       30
# 5          123        2008                     144                      126
# 6          128        2013                     216                      241
# 7          121        1998                      63                       15
# ...        ...         ...                     ...                      ...
# 4914        88        2009                     445                      181
# 4915       102        2011                     178                      153
# 4916        90        2001                     135                        0
# 4917       102        2016                     226                        0
# 4918        83        2006                      63                       12
#
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# Looking at the heatmap, it seems like the factors don't have a strong relationship. some of them have a moderate relationship such as when gross income of a movie is high, the number of critic for reviews is high. Also, new movies have more number of critic for reviews than the old movies as well.
#
# the seaborn correlation heatmaps are easier to look at than the matplotlib correlation heatmaps.

# %% [markdown]
# ## Scatterplots

# %%
# Create a scatterplot for the "title_year" and "gross" columns in seaborn

sns.lmplot(x = 'num_critic_for_reviews', y = 'gross', data = df)

# %% [markdown]
# The heatmap shows a moderate relationship between "number critic for reviews" and "gross income" of movies. However, when a scatterplots is made, the majority of the reviews are under 400 and starting to fade out as the numbers go up. Even there are some marks with high gross high reviews, the correlation might not be accurate.

# %% [markdown]
# ## Pair Plots

# %%
# Keep only the variables you want to use in the pair plot

pp = df[['duration', 'title_year', 'num_critic_for_reviews', 'imdb_score']]

# %%
# Create a pair plot 

g = sns.pairplot(pp)

# %% [markdown]
# This pair plot shows more varibales and give a bigger selections to choose from. For example, movies with high critic reviews tend to have higher IMDb score and also are movies from the 2000s. the seems like good variable to compare with others because it shows patterns differently compare to the others. Movies after the 1970s have more lower IMDb score and less longer movies durations (150 minutes or more)

# %% [markdown]
# ## Categorical Plots

# %%
# Use a histogram to visualize the distribution of the variables. 

sns.histplot(df['duration'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
df.loc[df['duration'] < 80, 'movie_time'] = 'short movie'
df.loc[(df['duration'] >= 70) & (df['duration'] < 180), 'movie_time'] = 'average movie'
df.loc[df['duration'] >= 180, 'movie_time'] = 'long movie'

# %%
df['movie_time'].value_counts(dropna = False)
# Out:
# average movie    3724
# long movie         53
# short movie        12
# Name: movie_time, dtype: int64

# %%
df.columns
# Out:
# Index(['duration', 'title_year', 'num_critic_for_reviews',
#        'director_facebook_likes', 'budget', 'gross',
#        'cast_total_facebook_likes', 'imdb_score', 'movie_time'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="imdb_score", y="duration", hue="movie_time", data=df)

# %%
# fig = g.get_figure()
g.savefig("Netcplot.png")

# %% [markdown]
# Based on the categorical plot, it's easy to "short movie" falls between imdb score of 6 and 7 and "long movies" have scores 5 and over. and the rest of the "average movies" fall under all imdb score.
# It could mean if you want to have a movie with a imdb score 5 and over, it will be good to choose either a short movie or a long movie.

# %% [markdown]
# ## Q7
#
# Answer: The average time of a movie is 110 minutes.
# Answer: Longer movies tends to be better movies (based on imdb score)
# Some new questions will be related to imdb_score.
# Question:
# how many movies are made in each year and how can they affect the imdb score?

# %% [markdown]
# ## Q8 - Hypotheses
#
# Long movies makes more money.
# number of critic reviews affect the imdb scores.
